# %%
import pandas as pd
# in below syntax convert data object to date type format
data=pd.read_csv('bigmac.csv',parse_dates=['Date'])
data.head(3)
# Out:
#         Date    Country  Price in US Dollars
# 0 2016-01-01  Argentina                 2.39
# 1 2016-01-01  Australia                 3.74
# 2 2016-01-01     Brazil                 3.35

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 652 entries, 0 to 651
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 652 non-null    datetime64[ns]
#  1   Country              652 non-null    object
#  2   Price in US Dollars  652 non-null    float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 12.8+ KB

# %%
data['Date'].nunique()
# Out:
# 12

# %%
data['Country'].nunique()
# Out:
# 58

# %%
# create multi index based on least uniques of column as a outer later and another one is inner layer for only data sufficient pupose
data.set_index(keys=['Date','Country'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-714b1f7afc23> in <module>
#       1 # create multi index based on least uniques of column as a outer later and another one is inner layer for only data sufficient pupose
# ----> 2 data.set_index(keys=['Date','Country'],inplace=True)
#
# c:\users\hello\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4548
#    4549         if missing:
# -> 4550             raise KeyError(f"None of {missing} are in the columns")
#    4551
#    4552         if inplace:
#
# KeyError: "None of ['Date', 'Country'] are in the columns"

# %%
data
# Out:
#                           Price in US Dollars
# Date       Country
# 2016-01-01 Argentina                     2.39
#            Australia                     3.74
#            Brazil                        3.35
#            Britain                       4.22
#            Canada                        4.14
# ...                                       ...
# 2010-01-01 Turkey                        3.83
#            UAE                           2.99
#            Ukraine                       1.83
#            United States                 3.58
#            Uruguay                       3.32
#
# [652 rows x 1 columns]

# %%
data.head(2)
# Out:
#                       Price in US Dollars
# Date       Country
# 2016-01-01 Argentina                 2.39
#            Australia                 3.74

# %%
# index.get_level_values() method helps to extract index level values
data.index
# Out:
# MultiIndex([('2016-01-01',      'Argentina'),
#             ('2016-01-01',      'Australia'),
#             ('2016-01-01',         'Brazil'),
#             ('2016-01-01',        'Britain'),
#             ('2016-01-01',         'Canada'),
#             ('2016-01-01',          'Chile'),
#             ('2016-01-01',          'China'),
#             ('2016-01-01',       'Colombia'),
#             ('2016-01-01',     'Costa Rica'),
#             ('2016-01-01', 'Czech Republic'),
#             ...
#             ('2010-01-01',      'Sri Lanka'),
#             ('2010-01-01',         'Sweden'),
#             ('2010-01-01',    'Switzerland'),
#             ('2010-01-01',         'Taiwan'),
#             ('2010-01-01',       'Thailand'),
#             ('2010-01-01',         'Turkey'),
#             ('2010-01-01',            'UAE'),
#             ('2010-01-01',        'Ukraine'),
#             ('2010-01-01',  'United States'),
#             ('2010-01-01',        'Uruguay')],
# ...

# %%
data.index.get_level_values(0)
# Out:
# DatetimeIndex(['2016-01-01', '2016-01-01', '2016-01-01', '2016-01-01',
#                '2016-01-01', '2016-01-01', '2016-01-01', '2016-01-01',
#                '2016-01-01', '2016-01-01',
#                ...
#                '2010-01-01', '2010-01-01', '2010-01-01', '2010-01-01',
#                '2010-01-01', '2010-01-01', '2010-01-01', '2010-01-01',
#                '2010-01-01', '2010-01-01'],
#               dtype='datetime64[ns]', name='Date', length=652, freq=None)

# %%
data.index.get_level_values(1)
# Out:
# Index(['Argentina', 'Australia', 'Brazil', 'Britain', 'Canada', 'Chile',
#        'China', 'Colombia', 'Costa Rica', 'Czech Republic',
#        ...
#        'Sri Lanka', 'Sweden', 'Switzerland', 'Taiwan', 'Thailand', 'Turkey',
#        'UAE', 'Ukraine', 'United States', 'Uruguay'],
#       dtype='object', name='Country', length=652)

# %%
# change the index levels names by using the set_names() method
data.index.set_names(names=['date','country'],inplace=True)

# %%
data.head(2)
# Out:
#                       Price in US Dollars
# date       country
# 2016-01-01 Argentina                 2.39
#            Australia                 3.74

# %%
# change the single index level name 
data.index.set_names(names='Date',level=0,inplace=True)

# %%
data.index.set_names(names='Country',level=1,inplace=True)

# %%
data.head(2)
# Out:
#                       Price in US Dollars
# Date       Country
# 2016-01-01 Argentina                 2.39
#            Australia                 3.74

# %%
# Sorting the index values using the sort_index() and changes both indexs
data.sort_index().head(1)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84

# %%
# only sort single index
data.sort_index(ascending=[True,False]).head(2)
# Out:
#                           Price in US Dollars
# Date       Country
# 2010-01-01 Uruguay                       3.32
#            United States                 3.58

# %%
# sort each level seporately
data.sort_index(level=0).head(2)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98

# %%
data.sort_index(level=1).head(2)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
# 2010-07-01 Argentina                 3.56

# %%
# extra rows from a multi index data frame
data.loc[('2010-01-01','Argentina')]
# Out:
# Price in US Dollars    1.84
# Name: (2010-01-01 00:00:00, Argentina), dtype: float64

# %%
data.sort_index(inplace=True)
data.loc['2010-01-01'].head(2)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98

# %%
data.loc[(['2010-01-01','2010-07-01'],),'Price in US Dollars']
# Out:
# Date        Country
# 2010-01-01  Argentina        1.84
#             Australia        3.98
#             Brazil           4.76
#             Britain          3.67
#             Canada           3.97
#                              ...
# 2010-07-01  Turkey           3.89
#             UAE              2.99
#             Ukraine          1.84
#             United States    3.73
#             Uruguay          3.74
# Name: Price in US Dollars, Length: 86, dtype: float64

# %%
# extract data using index value
data.iloc[10]
# Out:
# Price in US Dollars    5.99
# Name: (2010-01-01 00:00:00, Denmark), dtype: float64

# %%
data.index
# Out:
# MultiIndex([('2010-01-01',      'Argentina'),
#             ('2010-01-01',      'Australia'),
#             ('2010-01-01',         'Brazil'),
#             ('2010-01-01',        'Britain'),
#             ('2010-01-01',         'Canada'),
#             ('2010-01-01',          'Chile'),
#             ('2010-01-01',          'China'),
#             ('2010-01-01',       'Colombia'),
#             ('2010-01-01',     'Costa Rica'),
#             ('2010-01-01', 'Czech Republic'),
#             ...
#             ('2016-01-01',    'Switzerland'),
#             ('2016-01-01',         'Taiwan'),
#             ('2016-01-01',       'Thailand'),
#             ('2016-01-01',         'Turkey'),
#             ('2016-01-01',            'UAE'),
#             ('2016-01-01',        'Ukraine'),
#             ('2016-01-01',  'United States'),
#             ('2016-01-01',        'Uruguay'),
#             ('2016-01-01',      'Venezuela'),
#             ('2016-01-01',        'Vietnam')],
# ...

# %%
# transpose() method is used to convert rows as columns and columns as rows
killer=data.transpose()

# %%
data.head(1)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84

# %%
killer
# Out:
# Date                2010-01-01                                              \
# Country              Argentina Australia Brazil Britain Canada Chile China
# Price in US Dollars       1.84      3.98   4.76    3.67   3.97  3.18  1.83
#
# Date                                                    ...  2016-01-01  \
# Country             Colombia Costa Rica Czech Republic  ... Switzerland
# Price in US Dollars     3.91       3.52           3.71  ...        6.44
#
# Date                                                                    \
# Country             Taiwan Thailand Turkey   UAE Ukraine United States
# Price in US Dollars   2.08     3.09   3.41  3.54    1.54          4.93
#
# Date
# Country             Uruguay Venezuela Vietnam
# Price in US Dollars    3.74      0.66    2.67
#
# [1 rows x 652 columns]

# %%
killer['2010-07-01']['Argentina']
# Out:
# Price in US Dollars    3.56
# Name: Argentina, dtype: float64

# %%
killer.loc[('Price in US Dollars'),('2010-01-01','Canada'):('2010-07-01','Turkey')]
# Out:
# Date        Country
# 2010-01-01  Canada         3.97
#             Chile          3.18
#             China          1.83
#             Colombia       3.91
#             Costa Rica     3.52
#                            ...
# 2010-07-01  Sweden         6.56
#             Switzerland    6.19
#             Taiwan         2.34
#             Thailand       2.17
#             Turkey         3.89
# Name: Price in US Dollars, Length: 78, dtype: float64

# %%
# swaplevel() metod is used to convert index positions like outer level as inner level or inner level as outer level
data.swaplevel('Date','Country')

#data.swaplevel()
# Out:
#                           Price in US Dollars
# Country       Date
# Argentina     2010-01-01                 1.84
# Australia     2010-01-01                 3.98
# Brazil        2010-01-01                 4.76
# Britain       2010-01-01                 3.67
# Canada        2010-01-01                 3.97
# ...                                       ...
# Ukraine       2016-01-01                 1.54
# United States 2016-01-01                 4.93
# Uruguay       2016-01-01                 3.74
# Venezuela     2016-01-01                 0.66
# Vietnam       2016-01-01                 2.67
#
# [652 rows x 1 columns]

# %%
data.head(0)
# Out:
# Empty DataFrame
# Columns: [Price in US Dollars]
# Index: []

# %%
data=data.swaplevel().head(0)

# %%
data.head(0)
# Out:
# Empty DataFrame
# Columns: [Price in US Dollars]
# Index: []

# %%
data=data.swaplevel().head(0)

# %%
data.head(0)
# Out:
# Empty DataFrame
# Columns: [Price in US Dollars]
# Index: []

# %%
data.head(1)
# Out:
#         Date    Country  Price in US Dollars
# 0 2016-01-01  Argentina                 2.39

# %%
data.reset_index().head(1)
# Out:
#         Date    Country  Price in US Dollars
# 0 2016-01-01  Argentina                 2.39

# %%
data.head(1)
# Out:
#                       Price in US Dollars
# Date       Country
# 2016-01-01 Argentina                 2.39

# %%
# stack() method convert multiple columns to series or column is converted into row based data
data.set_index(['Date','Country'],inplace=True).head(1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-e7e416b9cf93> in <module>
#       1 # stack() method convert multiple columns to series
# ----> 2 data.set_index(['Date','Country'],inplace=True).head(1)
#
# c:\users\hello\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4548
#    4549         if missing:
# -> 4550             raise KeyError(f"None of {missing} are in the columns")
#    4551
#    4552         if inplace:
#
# KeyError: "None of ['Date', 'Country'] are in the columns"

# %%
data.stack()
# Out:
# Date        Country
# 2016-01-01  Argentina      Price in US Dollars    2.39
#             Australia      Price in US Dollars    3.74
#             Brazil         Price in US Dollars    3.35
#             Britain        Price in US Dollars    4.22
#             Canada         Price in US Dollars    4.14
#                                                   ...
# 2010-01-01  Turkey         Price in US Dollars    3.83
#             UAE            Price in US Dollars    2.99
#             Ukraine        Price in US Dollars    1.83
#             United States  Price in US Dollars    3.58
#             Uruguay        Price in US Dollars    3.32
# Length: 652, dtype: float64

# %%
data.stack().to_frame()
# Out:
#                                                  0
# Date       Country
# 2016-01-01 Argentina     Price in US Dollars  2.39
#            Australia     Price in US Dollars  3.74
#            Brazil        Price in US Dollars  3.35
#            Britain       Price in US Dollars  4.22
#            Canada        Price in US Dollars  4.14
# ...                                            ...
# 2010-01-01 Turkey        Price in US Dollars  3.83
#            UAE           Price in US Dollars  2.99
#            Ukraine       Price in US Dollars  1.83
#            United States Price in US Dollars  3.58
#            Uruguay       Price in US Dollars  3.32
#
# [652 rows x 1 columns]

# %%
data=pd.read_csv('worldstats.csv')
data.set_index(['country','year'],inplace=True)
data.head(1)
# Out:
#                   Population           GDP
# country    year
# Arab World 2015  392022276.0  2.530102e+12

# %%
data.stack().head(3)
# Out:
# country     year
# Arab World  2015  Population    3.920223e+08
#                   GDP           2.530102e+12
#             2014  Population    3.842226e+08
# dtype: float64

# %%
data=data.stack().to_frame()

# %%
data.head(3)
# Out:
#                                        0
# country    year
# Arab World 2015 Population  3.920223e+08
#                 GDP         2.530102e+12
#            2014 Population  3.842226e+08

# %%
data.columns
# Out:
# Int64Index([0], dtype='int64')

# %%
# change name of the column
data.rename(columns={'0':'data_values'},inplace=True)

# %%
undata=data
undata.head(2)
# Out:
#                                        0
# country    year
# Arab World 2015 Population  3.920223e+08
#                 GDP         2.530102e+12

# %%
# unstack() method is a reverse operatiion of stack() method
undata.unstack().head(3)
# Out:
#                           0
#                  Population           GDP
# country     year
# Afghanistan 1960  8994793.0  5.377778e+08
#             1961  9164945.0  5.488889e+08
#             1962  9343772.0  5.466667e+08

# %%
undata.unstack(1).head(5)
# unstack value is enter based on index position column which column is unstack
# Out:
#                                    0                              \
# year                            1960          1961          1962
# country
# Afghanistan Population  8.994793e+06  9.164945e+06  9.343772e+06
#             GDP         5.377778e+08  5.488889e+08  5.466667e+08
# Albania     Population           NaN           NaN           NaN
#             GDP                  NaN           NaN           NaN
# Algeria     Population  1.112489e+07  1.140486e+07  1.169015e+07
#
#                                                                   \
# year                            1963          1964          1965
# country
# Afghanistan Population  9.531555e+06  9.728645e+06  9.935358e+06
#             GDP         7.511112e+08  8.000000e+08  1.006667e+09
# Albania     Population           NaN           NaN           NaN
#             GDP                  NaN           NaN           NaN
# Algeria     Population  1.198513e+07  1.229597e+07  1.262695e+07
#
# ...

# %%
undata.unstack('year').head(5)
# Out:
#                                    0                              \
# year                            1960          1961          1962
# country
# Afghanistan Population  8.994793e+06  9.164945e+06  9.343772e+06
#             GDP         5.377778e+08  5.488889e+08  5.466667e+08
# Albania     Population           NaN           NaN           NaN
#             GDP                  NaN           NaN           NaN
# Algeria     Population  1.112489e+07  1.140486e+07  1.169015e+07
#
#                                                                   \
# year                            1963          1964          1965
# country
# Afghanistan Population  9.531555e+06  9.728645e+06  9.935358e+06
#             GDP         7.511112e+08  8.000000e+08  1.006667e+09
# Albania     Population           NaN           NaN           NaN
#             GDP                  NaN           NaN           NaN
# Algeria     Population  1.198513e+07  1.229597e+07  1.262695e+07
#
# ...

# %%
undata.unstack(-2).head(5)
# calculate a index from end position ( ending index start with -1)
# Out:
#                                    0                              \
# year                            1960          1961          1962
# country
# Afghanistan Population  8.994793e+06  9.164945e+06  9.343772e+06
#             GDP         5.377778e+08  5.488889e+08  5.466667e+08
# Albania     Population           NaN           NaN           NaN
#             GDP                  NaN           NaN           NaN
# Algeria     Population  1.112489e+07  1.140486e+07  1.169015e+07
#
#                                                                   \
# year                            1963          1964          1965
# country
# Afghanistan Population  9.531555e+06  9.728645e+06  9.935358e+06
#             GDP         7.511112e+08  8.000000e+08  1.006667e+09
# Albania     Population           NaN           NaN           NaN
#             GDP                  NaN           NaN           NaN
# Algeria     Population  1.198513e+07  1.229597e+07  1.262695e+07
#
# ...

# %%
undata.unstack().unstack().head(3)
# Out:
#                       0                                                  \
#              Population
# year               1960        1961        1962        1963        1964
# country
# Afghanistan   8994793.0   9164945.0   9343772.0   9531555.0   9728645.0
# Albania             NaN         NaN         NaN         NaN         NaN
# Algeria      11124892.0  11404859.0  11690152.0  11985130.0  12295973.0
#
#                                                                          ...  \
#                                                                          ...
# year               1965        1966        1967        1968        1969  ...
# country                                                                  ...
# Afghanistan   9935358.0  10148841.0  10368600.0  10599790.0  10849510.0  ...
# Albania             NaN         NaN         NaN         NaN         NaN  ...
# Algeria      12626953.0  12980269.0  13354197.0  13744383.0  14144437.0  ...
#
# ...

# %%
undata.unstack().unstack().unstack().head(4)
# Out:
#                year  country
# 0  Population  1960  Afghanistan     8994793.0
#                      Albania               NaN
#                      Algeria        11124892.0
#                      Andorra               NaN
# dtype: float64

# %%
# unstack the multiple levels
undata.unstack(level=[1,2])
# Out:
#                                0                                            \
# year                        2015                        2014
#                       Population           GDP    Population           GDP
# country
# Afghanistan         3.252656e+07  1.919944e+10  3.162751e+07  2.005019e+10
# Albania             2.889167e+06  1.145560e+10  2.893654e+06  1.327796e+10
# Algeria             3.966652e+07  1.668386e+11  3.893433e+07  2.135185e+11
# Andorra                      NaN           NaN           NaN           NaN
# Angola              2.502197e+07  1.026431e+11  2.422752e+07  1.267751e+11
# ...                          ...           ...           ...           ...
# West Bank and Gaza  4.422143e+06  1.267740e+10  4.294682e+06  1.271560e+10
# World               7.346633e+09  7.343364e+13  7.260780e+09  7.810634e+13
# Yemen, Rep.                  NaN           NaN           NaN           NaN
# Zambia              1.621177e+07  2.120156e+10  1.572134e+07  2.713464e+10
# ...

# %%
undata.unstack('year')
# Out:
#                                    0                              \
# year                            1960          1961          1962
# country
# Afghanistan Population  8.994793e+06  9.164945e+06  9.343772e+06
#             GDP         5.377778e+08  5.488889e+08  5.466667e+08
# Albania     Population           NaN           NaN           NaN
#             GDP                  NaN           NaN           NaN
# Algeria     Population  1.112489e+07  1.140486e+07  1.169015e+07
# ...                              ...           ...           ...
# Yemen, Rep. GDP                  NaN           NaN           NaN
# Zambia      Population  3.049586e+06  3.142848e+06  3.240664e+06
#             GDP         6.987397e+08  6.823597e+08  6.792797e+08
# Zimbabwe    Population  3.752390e+06  3.876638e+06  4.006262e+06
#             GDP         1.052990e+09  1.096647e+09  1.117602e+09
#
#                                                                   \
# ...

# %%
undata.unstack('year',fill_value='value not mentioned').head(5)
#fill_ value parameter used to fill the null in data frame
# Out:
#                                           0                       \
# year                                   1960                 1961
# country
# Afghanistan Population          8.99479e+06          9.16494e+06
#             GDP                 5.37778e+08          5.48889e+08
# Albania     Population  value not mentioned  value not mentioned
#             GDP         value not mentioned  value not mentioned
# Algeria     Population          1.11249e+07          1.14049e+07
#
#                                                                   \
# year                                   1962                 1963
# country
# Afghanistan Population          9.34377e+06          9.53156e+06
#             GDP                 5.46667e+08          7.51111e+08
# Albania     Population  value not mentioned  value not mentioned
#             GDP         value not mentioned  value not mentioned
# Algeria     Population          1.16902e+07          1.19851e+07
#
# ...

# %%
# pivot() method is used to convert the columns as column header
import pandas as pd
data=pd.read_csv('salesmen.csv')

# %%
data.head(3)
# Out:
#      Date Salesman  Revenue
# 0  1/1/16      Bob     7172
# 1  1/2/16      Bob     6362
# 2  1/3/16      Bob     5982

# %%
data.set_index('Date')
# Out:
#          Salesman  Revenue
# Date
# 1/1/16        Bob     7172
# 1/2/16        Bob     6362
# 1/3/16        Bob     5982
# 1/4/16        Bob     7917
# 1/5/16        Bob     7837
# ...           ...      ...
# 12/27/16    Oscar      835
# 12/28/16    Oscar     3073
# 12/29/16    Oscar     6424
# 12/30/16    Oscar     7088
# 12/31/16    Oscar     8408
#
# [1830 rows x 2 columns]

# %%
data['Salesman'].nunique()
# Out:
# 5

# %%
data.nunique()
# Out:
# Date         366
# Salesman       5
# Revenue     1676
# dtype: int64

# %%
data.pivot(index='Date',columns='Salesman',values='Revenue').head(5)
# Out:
# Salesman   Bob  Dave   Jeb  Oscar  Ronald
# Date
# 1/1/16    7172  1864  4430   5250    2639
# 1/10/16   7543  7105   301   7663    8267
# 1/11/16   1053  6851  9489   8888    1340
# 1/12/16   4362  7147  8719   3092     279
# 1/13/16   6812  6160  2349   6139    7540

# %%
# pivot_table() method is used to perform ms excel type operations in data frame
data.pivot_table(index='Date', values="Revenue",aggfunc='mean').head(2)
# Out:
#          Revenue
# Date
# 1/1/16    4271.0
# 1/10/16   6175.8

# %%
data=pd.read_csv('foods.csv')

# %%
data.head(2)
# Out:
#   First Name  Gender      City Frequency     Item  Spend
# 0      Wanda  Female  Stamford    Weekly   Burger  15.66
# 1       Eric    Male  Stamford     Daily  Chalupa  10.56

# %%
# index parameter tell which column to used as grouping purpose
data.pivot_table(values='Spend',index='Gender',aggfunc='sum')
# Out:
#            Spend
# Gender
# Female  25963.33
# Male    24106.04

# %%
data.pivot_table(values='Spend',index=['Gender','City','Item'],aggfunc="max")
# Out:
#                                Spend
# Gender City         Item
# Female New York     Burger     98.96
#                     Burrito    92.25
#                     Chalupa    98.43
#                     Donut      95.63
#                     Ice Cream  97.83
#                     Sushi      99.51
#        Philadelphia Burger     97.79
#                     Burrito    96.79
#                     Chalupa    99.29
#                     Donut      96.52
#                     Ice Cream  88.14
#                     Sushi      99.02
#        Stamford     Burger     85.06
#                     Burrito    99.21
#                     Chalupa    98.78
#                     Donut      91.75
#                     Ice Cream  97.44
#                     Sushi      95.43
# Male   New York     Burger     90.32
#                     Burrito    98.04
#                     Chalupa    96.44
#                     Donut      86.70
#                     Ice Cream  97.65
# ...

# %%
# columns parameter denotes which column set as column of new data
data.pivot_table(values='Spend',index=['City','Item'],columns='Gender',aggfunc='sum').head(3)
# Out:
# Gender             Female     Male
# City     Item
# New York Burger   1239.04  1294.09
#          Burrito   978.95  1399.40
#          Chalupa   876.58  1227.77

# %%
# pd.melt() mehod perform is reverse type of pivot_table
data=pd.read_csv('quarters.csv')

# %%
pd.melt(data,id_vars='Salesman',var_name="quater",value_name='Revenue')
# Out:
#    Salesman quater  Revenue
# 0     Boris     Q1   602908
# 1       Bob     Q1    43790
# 2     Tommy     Q1   392668
# 3    Travis     Q1   834663
# 4    Donald     Q1   580935
# 5       Ted     Q1   656644
# 6       Jeb     Q1   486141
# 7     Stacy     Q1   479662
# 8    Morgan     Q1   992673
# 9     Boris     Q2   233879
# 10      Bob     Q2   514863
# 11    Tommy     Q2   113579
# 12   Travis     Q2   266785
# 13   Donald     Q2   411379
# 14      Ted     Q2    70803
# 15      Jeb     Q2   600753
# 16    Stacy     Q2   742806
# 17   Morgan     Q2   879183
# 18    Boris     Q3   354479
# 19      Bob     Q3   297151
# 20    Tommy     Q3   430882
# 21   Travis     Q3   749238
# 22   Donald     Q3   110390
# 23      Ted     Q3   375948
# 24      Jeb     Q3   742716
# 25    Stacy     Q3   770712
# 26   Morgan     Q3    37945
# 27    Boris     Q4    32704
# 28      Bob     Q4   544493
# 29    Tommy     Q4   247231
# 30   Travis     Q4   570524
# 31   Donald     Q4   651572
# ...
