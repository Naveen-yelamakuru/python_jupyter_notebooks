# %%
import pandas as pd
data=pd.read_csv("sample.csv")
data
# Out:
#      Serial Number               Company Name  Employee Markme  \
# 0    9788189999599             TALES OF SHIVA             Mark
# 1    9780099578079  1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2    9780198082897                   MY KUMAN             Mark
# 3    9780007880331    THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4    9780545060455           THE BLACK CIRCLE             Mark
# ..             ...                        ...              ...
# 494  9789384147631     GRAMMER & VOCABULARY 4             Mark
# 495  9789384147648     GRAMMER & VOCABULARY 5             Mark
# 496  9789384147655     GRAMMER & VOCABULARY 6             Mark
# 497  9789384147044         ENGLISH OLYMPIAD-5             NILL
# 498  9789384147068       MarkITIK KAHANIYAN 1             Mark
#
#             Description  Leave
# 0                  mark      0
# 1                  Mark      0
# 2                  Mark      0
# 3    4TH HARPER COLLINS      2
# 4    4TH HARPER COLLINS      0
# ...

# %%
data=pd.read_csv('record.csv')

# %%
data.dtypes
# Out:
# Emp ID                      int64
# Name Prefix                object
# First Name                 object
# Middle Initial             object
# Last Name                  object
# Gender                     object
# E Mail                     object
# Father's Name              object
# Mother's Name              object
# Mother's Maiden Name       object
# Date of Birth              object
# Time of Birth              object
# Age in Yrs.               float64
# Weight in Kgs.              int64
# Date of Joining            object
# Quarter of Joining         object
# Half of Joining            object
# Year of Joining             int64
# Month of Joining            int64
# Month Name of Joining      object
# Short Month                object
# Day of Joining              int64
# DOW of Joining             object
# Short DOW                  object
# Age in Company (Years)    float64
# Salary                      int64
# Last % Hike                object
# ...

# %%
data.dtypes.value_counts()
# Out:
# object     28
# int64       7
# float64     2
# dtype: int64

# %%
data.nunique()
# Out:
# Emp ID                    1000
# Name Prefix                  7
# First Name                 792
# Middle Initial              26
# Last Name                  640
# Gender                       2
# E Mail                    1000
# Father's Name             1000
# Mother's Name             1000
# Mother's Maiden Name       634
# Date of Birth              977
# Time of Birth              992
# Age in Yrs.                889
# Weight in Kgs.              51
# Date of Joining            942
# Quarter of Joining           4
# Half of Joining              2
# Year of Joining             38
# Month of Joining            12
# Month Name of Joining       12
# Short Month                 12
# Day of Joining              31
# DOW of Joining               7
# Short DOW                    7
# Age in Company (Years)     811
# Salary                     997
# Last % Hike                 31
# SSN                       1000
# Phone No.                 1000
# Place Name                 880
# ...

# %%
data['State'].unique()
# Out:
# array(['NV', 'MI', 'KY', 'IN', 'AK', 'VA', 'TX', 'TN', 'IL', 'PA', 'CA',
#        'OR', 'IA', 'OK', 'MD', 'NY', 'NE', 'WA', 'LA', 'ME', 'MT', 'FL',
#        'WY', 'AR', 'WV', 'MA', 'MS', 'MO', 'GA', 'NC', 'NJ', 'OH', 'KS',
#        'ID', 'NH', 'CT', 'CO', 'MN', 'AL', 'WI', 'ND', 'SD', 'UT', 'NM',
#        'AZ', 'DE', 'SC', 'VT', 'DC', 'RI'], dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 37 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Emp ID                  1000 non-null   int64
#  1   Name Prefix             1000 non-null   object
#  2   First Name              1000 non-null   object
#  3   Middle Initial          1000 non-null   object
#  4   Last Name               1000 non-null   object
#  5   Gender                  1000 non-null   object
#  6   E Mail                  1000 non-null   object
#  7   Father's Name           1000 non-null   object
#  8   Mother's Name           1000 non-null   object
#  9   Mother's Maiden Name    1000 non-null   object
#  10  Date of Birth           1000 non-null   object
#  11  Time of Birth           1000 non-null   object
#  12  Age in Yrs.             1000 non-null   float64
#  13  Weight in Kgs.          1000 non-null   int64
# ...

# %%
import pandas as pd
data['County']=data['County'].astype('category')
data['Salary']=data['Salary'].astype('int')
data["State"]=data['State'].astype('category')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 37 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Emp ID                  1000 non-null   int64
#  1   Name Prefix             1000 non-null   object
#  2   First Name              1000 non-null   object
#  3   Middle Initial          1000 non-null   object
#  4   Last Name               1000 non-null   object
#  5   Gender                  1000 non-null   object
#  6   E Mail                  1000 non-null   object
#  7   Father's Name           1000 non-null   object
#  8   Mother's Name           1000 non-null   object
#  9   Mother's Maiden Name    1000 non-null   object
#  10  Date of Birth           1000 non-null   object
#  11  Time of Birth           1000 non-null   object
#  12  Age in Yrs.             1000 non-null   float64
#  13  Weight in Kgs.          1000 non-null   int64
# ...

# %%
mask=((data['Region']=='Midwest')&(data['City']=='Irons'))
data[mask]
# Out:
#    Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 1  304721         Mr.  Nathaniel              Z     Burke      M
#
#                         E Mail  Father's Name Mother's Name  \
# 1  nathaniel.burke@walmart.com  Derrick Burke  Phoebe Burke
#
#   Mother's Maiden Name  ...          SSN    Phone No.   Place Name  County  \
# 1                 Pugh  ...  550-99-9897  231-765-6923       Irons    Lake
#
#     City State    Zip   Region  User Name        Password
# 1  Irons    MI  49644  Midwest    nzburke  tPA@4Wh9Ja$+Ln
#
# [1 rows x 37 columns]

# %%
mask=(((data['Region']=='Midwest')&(data['City']!='Irons'))&(data['Gender']=='M'))
data[mask]
# Out:
#      Emp ID Name Prefix First Name Middle Initial   Last Name Gender  \
# 14   707520         Mr.   Bernardo              L      Austin      M
# 44   865495         Mr.    Thurman              J        Good      M
# 46   279563         Mr.      Clint              A     Bridges      M
# 53   323914         Mr.     German              M      Carney      M
# 54   928739        Hon.    Micheal              A     Shannon      M
# ..      ...         ...        ...            ...         ...    ...
# 981  523887         Mr.    Gilbert              L        Luna      M
# 985  953997         Mr.     Graham              F  Hutchinson      M
# 987  352882         Dr.        Lon              P      Harper      M
# 992  601808         Mr.       Olin              N        Case      M
# 996  597409         Mr.       Luke              S      Turner      M
#
#                               E Mail        Father's Name       Mother's Name  \
# ...

# %%
data[(data['Zip']>=68326)|(data['Gender']=='F')]
# Out:
#      Emp ID Name Prefix First Name Middle Initial  Last Name Gender  \
# 0    850297         Ms.     Shawna              W       Buck      F
# 2    412317        Drs.  Elisabeth              W     Foster      F
# 3    621375        Mrs.     Briana              C  Lancaster      F
# 4    787549        Hon.    Estella              L     Potter      F
# 6    795934         Ms.    Melinda              L      Lopez      F
# ..      ...         ...        ...            ...        ...    ...
# 994  172440         Dr.       Cody              H    Allison      M
# 995  568435         Ms.     Bonnie              K      Baker      F
# 997  359608        Hon.        Eva              S     Holman      F
# 998  803426        Mrs.    Maritza              H  Christian      F
# 999  669618        Drs.    Phyllis              H     Dudley      F
#
#                               E Mail      Father's Name        Mother's Name  \
# ...

# %%
mask=data['Place Name'].isin(['Las Vegas','Irons','Munster'])
data[mask]
# Out:
#    Emp ID Name Prefix First Name Middle Initial  Last Name Gender  \
# 0  850297         Ms.     Shawna              W       Buck      F
# 1  304721         Mr.  Nathaniel              Z      Burke      M
# 3  621375        Mrs.     Briana              C  Lancaster      F
#
#                         E Mail      Father's Name     Mother's Name  \
# 0        shawna.buck@gmail.com       Rosario Buck       Keisha Buck
# 1  nathaniel.burke@walmart.com      Derrick Burke      Phoebe Burke
# 3   briana.lancaster@yahoo.com  Jeffrey Lancaster  Shelby Lancaster
#
#   Mother's Maiden Name  ...          SSN    Phone No.   Place Name  County  \
# 0            Hendricks  ...  222-11-7603  702-771-7149   Las Vegas   Clark
# 1                 Pugh  ...  550-99-9897  231-765-6923       Irons    Lake
# 3                Weiss  ...  534-71-1053  219-623-8216     Munster    Lake
#
#         City State    Zip   Region    User Name         Password
# ...

# %%
mask=data['Region'].notnull()
data[mask]
# Out:
#      Emp ID Name Prefix First Name Middle Initial  Last Name Gender  \
# 0    850297         Ms.     Shawna              W       Buck      F
# 1    304721         Mr.  Nathaniel              Z      Burke      M
# 2    412317        Drs.  Elisabeth              W     Foster      F
# 3    621375        Mrs.     Briana              C  Lancaster      F
# 4    787549        Hon.    Estella              L     Potter      F
# ..      ...         ...        ...            ...        ...    ...
# 995  568435         Ms.     Bonnie              K      Baker      F
# 996  597409         Mr.       Luke              S     Turner      M
# 997  359608        Hon.        Eva              S     Holman      F
# 998  803426        Mrs.    Maritza              H  Christian      F
# 999  669618        Drs.    Phyllis              H     Dudley      F
#
#                               E Mail      Father's Name        Mother's Name  \
# ...

# %%
mask=data['Region'].isnull()
data[mask]
# Out:
# Empty DataFrame
# Columns: [Emp ID, Name Prefix, First Name, Middle Initial, Last Name, Gender, E Mail, Father's Name, Mother's Name, Mother's Maiden Name, Date of Birth, Time of Birth, Age in Yrs., Weight in Kgs., Date of Joining, Quarter of Joining, Half of Joining, Year of Joining, Month of Joining, Month Name of Joining, Short Month, Day of Joining, DOW of Joining, Short DOW, Age in Company (Years), Salary, Last % Hike, SSN, Phone No. , Place Name, County, City, State, Zip, Region, User Name, Password]
# Index: []
#
# [0 rows x 37 columns]

# %%
killr=data['Zip']
mask=data['Zip']<=60000
killr[mask]
# Out:
# 1      49644
# 2      40501
# 3      46321
# 5      20134
# 7      20171
#        ...
# 990     4456
# 993    22402
# 995    53149
# 996    49325
# 998     6910
# Name: Zip, Length: 638, dtype: int64

# %%
data[data['Zip'].between(60000,70000)]
# Out:
#      Emp ID Name Prefix First Name Middle Initial  Last Name Gender  \
# 9    532002         Ms.      Madge              V    Sargent      F
# 20   308617        Mrs.     Aileen              D  Blanchard      F
# 36   893976         Ms.    Beverly              I    Rosales      F
# 39   297741         Ms.       Lynn              E       Pena      F
# 44   865495         Mr.    Thurman              J       Good      M
# ..      ...         ...        ...            ...        ...    ...
# 959  779374       Prof.     Dudley              V    Elliott      M
# 966  186298        Mrs.      Luisa              Q   Mcintyre      F
# 978  712170         Mr.   Theodore              T       Dale      M
# 987  352882         Dr.        Lon              P     Harper      M
# 992  601808         Mr.       Olin              N       Case      M
#
#                            E Mail    Father's Name     Mother's Name  \
# 9           madge.sargent@aol.com     Luke Sargent      Judy Sargent
# ...

# %%
# duplicated method and drop_duplicates() operation wise both are equal but major difference is duplicated method used series and drop_duplicates used dataframe
data[data['State'].duplicated()]
# Out:
#      Emp ID Name Prefix First Name Middle Initial  Last Name Gender  \
# 7    159108        Mrs.     Shanna              U      Silva      F
# 13   966375         Dr.     Mathew              O      Hodge      M
# 16   265124         Ms.      Tonia              J      Burns      F
# 18   369712        Mrs.    Yesenia              B   Guerrero      F
# 23   513011         Ms.       Tara              Y     Forbes      F
# ..      ...         ...        ...            ...        ...    ...
# 995  568435         Ms.     Bonnie              K      Baker      F
# 996  597409         Mr.       Luke              S     Turner      M
# 997  359608        Hon.        Eva              S     Holman      F
# 998  803426        Mrs.    Maritza              H  Christian      F
# 999  669618        Drs.    Phyllis              H     Dudley      F
#
#                               E Mail    Father's Name        Mother's Name  \
# ...

# %%
data
# Out:
#      Emp ID Name Prefix First Name Middle Initial  Last Name Gender  \
# 0    850297         Ms.     Shawna              W       Buck      F
# 1    304721         Mr.  Nathaniel              Z      Burke      M
# 2    412317        Drs.  Elisabeth              W     Foster      F
# 3    621375        Mrs.     Briana              C  Lancaster      F
# 4    787549        Hon.    Estella              L     Potter      F
# ..      ...         ...        ...            ...        ...    ...
# 995  568435         Ms.     Bonnie              K      Baker      F
# 996  597409         Mr.       Luke              S     Turner      M
# 997  359608        Hon.        Eva              S     Holman      F
# 998  803426        Mrs.    Maritza              H  Christian      F
# 999  669618        Drs.    Phyllis              H     Dudley      F
#
#                               E Mail      Father's Name        Mother's Name  \
# ...

# %%
data.drop_duplicates(subset=['First Name','Zip'])
# Out:
#      Emp ID Name Prefix First Name Middle Initial  Last Name Gender  \
# 0    850297         Ms.     Shawna              W       Buck      F
# 1    304721         Mr.  Nathaniel              Z      Burke      M
# 2    412317        Drs.  Elisabeth              W     Foster      F
# 3    621375        Mrs.     Briana              C  Lancaster      F
# 4    787549        Hon.    Estella              L     Potter      F
# ..      ...         ...        ...            ...        ...    ...
# 995  568435         Ms.     Bonnie              K      Baker      F
# 996  597409         Mr.       Luke              S     Turner      M
# 997  359608        Hon.        Eva              S     Holman      F
# 998  803426        Mrs.    Maritza              H  Christian      F
# 999  669618        Drs.    Phyllis              H     Dudley      F
#
#                               E Mail      Father's Name        Mother's Name  \
# ...

# %%
data.dtypes
# Out:
# Serial Number       int64
# Company Name       object
# Employee Markme    object
# Description        object
# Leave               int64
# dtype: object

# %%
data['data of join']='1999-10-12'

# %%
data
# Out:
#      Serial Number               Company Name  Employee Markme  \
# 0    9788189999599             TALES OF SHIVA             Mark
# 1    9780099578079  1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2    9780198082897                   MY KUMAN             Mark
# 3    9780007880331    THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4    9780545060455           THE BLACK CIRCLE             Mark
# ..             ...                        ...              ...
# 494  9789384147631     GRAMMER & VOCABULARY 4             Mark
# 495  9789384147648     GRAMMER & VOCABULARY 5             Mark
# 496  9789384147655     GRAMMER & VOCABULARY 6             Mark
# 497  9789384147044         ENGLISH OLYMPIAD-5             NILL
# 498  9789384147068       MarkITIK KAHANIYAN 1             Mark
#
#             Description  Leave data of join
# 0                  mark      0   1999-10-12
# 1                  Mark      0   1999-10-12
# 2                  Mark      0   1999-10-12
# ...

# %%
data.dtypes
# Out:
# Serial Number       int64
# Company Name       object
# Employee Markme    object
# Description        object
# Leave               int64
# data of join       object
# dtype: object

# %%
#convert object type to date time type of object use to_datetime() method
pd.to_datetime(data['data of join'])
# Out:
# 0     1999-10-12
# 1     1999-10-12
# 2     1999-10-12
# 3     1999-10-12
# 4     1999-10-12
#          ...
# 494   1999-10-12
# 495   1999-10-12
# 496   1999-10-12
# 497   1999-10-12
# 498   1999-10-12
# Name: data of join, Length: 499, dtype: datetime64[ns]

# %%
data['is company']='True'

# %%
data
# Out:
#      Serial Number               Company Name  Employee Markme  \
# 0    9788189999599             TALES OF SHIVA             Mark
# 1    9780099578079  1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2    9780198082897                   MY KUMAN             Mark
# 3    9780007880331    THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4    9780545060455           THE BLACK CIRCLE             Mark
# ..             ...                        ...              ...
# 494  9789384147631     GRAMMER & VOCABULARY 4             Mark
# 495  9789384147648     GRAMMER & VOCABULARY 5             Mark
# 496  9789384147655     GRAMMER & VOCABULARY 6             Mark
# 497  9789384147044         ENGLISH OLYMPIAD-5             NILL
# 498  9789384147068       MarkITIK KAHANIYAN 1             Mark
#
#             Description  Leave data of join is company
# 0                  mark      0   1999-10-12       True
# 1                  Mark      0   1999-10-12       True
# ...

# %%
data
# Out:
#      Serial Number               Company Name  Employee Markme  \
# 0    9788189999599             TALES OF SHIVA             Mark
# 1    9780099578079  1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2    9780198082897                   MY KUMAN             Mark
# 3    9780007880331    THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4    9780545060455           THE BLACK CIRCLE             Mark
# ..             ...                        ...              ...
# 494  9789384147631     GRAMMER & VOCABULARY 4             Mark
# 495  9789384147648     GRAMMER & VOCABULARY 5             Mark
# 496  9789384147655     GRAMMER & VOCABULARY 6             Mark
# 497  9789384147044         ENGLISH OLYMPIAD-5             NILL
# 498  9789384147068       MarkITIK KAHANIYAN 1             Mark
#
#             Description  Leave data of join is company
# 0                  mark      0   1999-10-12       True
# 1                  Mark      0   1999-10-12       True
# ...

# %%
data["is company"].astype('bool')
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 494    True
# 495    True
# 496    True
# 497    True
# 498    True
# Name: is company, Length: 499, dtype: bool

# %%
data.dtypes
# Out:
# Serial Number       int64
# Company Name       object
# Employee Markme    object
# Description        object
# Leave               int64
# data of join       object
# is company         object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Serial Number    499 non-null    int64
#  1   Company Name     499 non-null    object
#  2   Employee Markme  494 non-null    object
#  3   Description      499 non-null    object
#  4   Leave            499 non-null    int64
#  5   data of join     499 non-null    object
#  6   is company       499 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 17.6+ KB

# %%
# filter a data frame based on a condition 
data
# Out:
#      Serial Number               Company Name  Employee Markme  \
# 0    9788189999599             TALES OF SHIVA             Mark
# 1    9780099578079  1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2    9780198082897                   MY KUMAN             Mark
# 3    9780007880331    THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4    9780545060455           THE BLACK CIRCLE             Mark
# ..             ...                        ...              ...
# 494  9789384147631     GRAMMER & VOCABULARY 4             Mark
# 495  9789384147648     GRAMMER & VOCABULARY 5             Mark
# 496  9789384147655     GRAMMER & VOCABULARY 6             Mark
# 497  9789384147044         ENGLISH OLYMPIAD-5             NILL
# 498  9789384147068       MarkITIK KAHANIYAN 1             Mark
#
#             Description  Leave data of join is company
# 0                  mark      0   1999-10-12       True
# 1                  Mark      0   1999-10-12       True
# ...

# %%
data.dtypes.value_counts()
# Out:
# object    5
# int64     2
# dtype: int64

# %%
# this method helps to find unique values in columns
data.nunique()
# Out:
# Serial Number      499
# Company Name       494
# Employee Markme    267
# Description         66
# Leave                7
# data of join         1
# is company           1
# dtype: int64

# %%
data[data['Company Name']=='GRAMMER & VOCABULARY 6']
# Out:
#      Serial Number            Company Name Employee Markme       Description  \
# 496  9789384147655  GRAMMER & VOCABULARY 6            Mark  BLUE BERRY BOOKS
#
#      Leave data of join is company
# 496      0   1999-10-12       True

# %%
data[data['Description']=='Mark']
# Out:
#    Serial Number               Company Name  Employee Markme Description  \
# 1  9780099578079  1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI        Mark
# 2  9780198082897                   MY KUMAN             Mark        Mark
#
#    Leave data of join is company
# 1      0   1999-10-12       True
# 2      0   1999-10-12       True

# %%
clear=data['Description']!='Mark'

# %%
data[clear]
# Out:
#                                 Company Name Employee Markme  \
# Serial Number
# 9788189999599                 TALES OF SHIVA            Mark
# 9780007880331        THE GOD OF SMAAL THINGS   ARUNDHATI ROY
# 9780545060455               THE BLACK CIRCLE            Mark
# 9788126525072  THE THREE LAWS OF PERFORMANCE            Mark
# 9789381626610              CHAMarkKYA MANTRA            Mark
# ...                                      ...             ...
# 9789384147631         GRAMMER & VOCABULARY 4            Mark
# 9789384147648         GRAMMER & VOCABULARY 5            Mark
# 9789384147655         GRAMMER & VOCABULARY 6            Mark
# 9789384147044             ENGLISH OLYMPIAD-5            NILL
# 9789384147068           MarkITIK KAHANIYAN 1            Mark
#
#                       Description  Leave
# Serial Number
# 9788189999599                mark      0
# 9780007880331  4TH HARPER COLLINS      2
# 9780545060455  4TH HARPER COLLINS      0
# ...

# %%
data
# Out:
#      Serial Number               Company Name  Employee Markme  \
# 0    9788189999599             TALES OF SHIVA             Mark
# 1    9780099578079  1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2    9780198082897                   MY KUMAN             Mark
# 3    9780007880331    THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4    9780545060455           THE BLACK CIRCLE             Mark
# ..             ...                        ...              ...
# 494  9789384147631     GRAMMER & VOCABULARY 4             Mark
# 495  9789384147648     GRAMMER & VOCABULARY 5             Mark
# 496  9789384147655     GRAMMER & VOCABULARY 6             Mark
# 497  9789384147044         ENGLISH OLYMPIAD-5             NILL
# 498  9789384147068       MarkITIK KAHANIYAN 1             Mark
#
#             Description  Leave data of join is company
# 0                  mark      0   1999-10-12       True
# 1                  Mark      0   1999-10-12       True
# ...

# %%
import pandas as pd
data=pd.read_csv('sample.csv')

# %%
data.head(3)
# Out:
#    Serial Number               Company Name  Employee Markme Description  \
# 0  9788189999599             TALES OF SHIVA             Mark        mark
# 1  9780099578079  1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI        Mark
# 2  9780198082897                   MY KUMAN             Mark        Mark
#
#    Leave
# 0      0
# 1      0
# 2      0

# %%
data.set_index('Description')
# Out:
#                     Serial Number               Company Name  Employee Markme  \
# Description
# mark                9788189999599             TALES OF SHIVA             Mark
# Mark                9780099578079  1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# Mark                9780198082897                   MY KUMAN             Mark
# 4TH HARPER COLLINS  9780007880331    THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4TH HARPER COLLINS  9780545060455           THE BLACK CIRCLE             Mark
# ...                           ...                        ...              ...
# BLUE BERRY BOOKS    9789384147631     GRAMMER & VOCABULARY 4             Mark
# BLUE BERRY BOOKS    9789384147648     GRAMMER & VOCABULARY 5             Mark
# BLUE BERRY BOOKS    9789384147655     GRAMMER & VOCABULARY 6             Mark
# BLUE BERRY BOOKS    9789384147044         ENGLISH OLYMPIAD-5             NILL
# BLUE BERRY BOOKS    9789384147068       MarkITIK KAHANIYAN 1             Mark
#
# ...

# %%
data.reset_index().head(3)
# Out:
#    index  Serial Number               Company Name  Employee Markme  \
# 0      0  9788189999599             TALES OF SHIVA             Mark
# 1      1  9780099578079  1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2      2  9780198082897                   MY KUMAN             Mark
#
#   Description  Leave
# 0        mark      0
# 1        Mark      0
# 2        Mark      0

# %%
data['Company Name'].iloc[3]
# Out:
# 'THE GOD OF SMAAL THINGS'
