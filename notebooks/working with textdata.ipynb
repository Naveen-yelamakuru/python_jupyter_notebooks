# %%
import pandas as pd
data=pd.read_csv('record.csv')
data
# Out:
#      Emp ID Name Prefix First Name Middle Initial  Last Name Gender  \
# 0    850297         Ms.     Shawna              W       Buck      F
# 1    304721         Mr.  Nathaniel              Z      Burke      M
# 2    412317        Drs.  Elisabeth              W     Foster      F
# 3    621375        Mrs.     Briana              C  Lancaster      F
# 4    787549        Hon.    Estella              L     Potter      F
# ..      ...         ...        ...            ...        ...    ...
# 995  568435         Ms.     Bonnie              K      Baker      F
# 996  597409         Mr.       Luke              S     Turner      M
# 997  359608        Hon.        Eva              S     Holman      F
# 998  803426        Mrs.    Maritza              H  Christian      F
# 999  669618        Drs.    Phyllis              H     Dudley      F
#
#                               E Mail      Father's Name        Mother's Name  \
# ...

# %%
data.columns
# Out:
# Index(['Emp ID', 'Name Prefix', 'First Name', 'Middle Initial', 'Last Name',
#        'Gender', 'E Mail', 'Father's Name', 'Mother's Name',
#        'Mother's Maiden Name', 'Date of Birth', 'Time of Birth', 'Age in Yrs.',
#        'Weight in Kgs.', 'Date of Joining', 'Quarter of Joining',
#        'Half of Joining', 'Year of Joining', 'Month of Joining',
#        'Month Name of Joining', 'Short Month', 'Day of Joining',
#        'DOW of Joining', 'Short DOW', 'Age in Company (Years)', 'Salary',
#        'Last % Hike', 'SSN', 'Phone No. ', 'Place Name', 'County', 'City',
#        'State', 'Zip', 'Region', 'User Name', 'Password'],
#       dtype='object')

# %%
data.drop(["Father's Name", "Mother's Name",
       "Mother's Maiden Name", 'Date of Birth', 'Time of Birth', 'Age in Yrs.',
       'Weight in Kgs.', 'Date of Joining', 'Quarter of Joining',
       'Half of Joining', 'Year of Joining', 'Month of Joining',
       'Month Name of Joining', 'Short Month', 'Day of Joining',
       'DOW of Joining', 'Short DOW', 'Age in Company (Years)', 'Salary',
       'Last % Hike', 'SSN', 'Phone No. ', 'Place Name', 'County', 'City',
       'State', 'Zip', 'Region', 'User Name', 'Password'],axis=1,inplace=True)

# %%
data.head(3)
# Out:
#    Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 0  850297         Ms.     Shawna              W      Buck      F
# 1  304721         Mr.  Nathaniel              Z     Burke      M
# 2  412317        Drs.  Elisabeth              W    Foster      F
#
#                         E Mail
# 0        shawna.buck@gmail.com
# 1  nathaniel.burke@walmart.com
# 2   elisabeth.foster@gmail.com

# %%
data.set_index("First Name",inplace=True)

# %%
 data.drop("(850297,E Mail)",axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-e9a1a5840437> in <module>
# ----> 1 data.drop("(850297,E Mail)",axis=1,inplace=True)
#
# c:\users\hello\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4160                 weight  1.0     0.8
#    4161         """
# -> 4162         return super().drop(
#    4163             labels=labels,
#    4164             axis=axis,
#
# c:\users\hello\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3882         for axis, labels in axes.items():
#    3883             if labels is not None:
# -> 3884                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3885
# ...

# %%
data.head(3)
# Out:
#             Emp ID Name Prefix Middle Initial Last Name Gender  \
# First Name
# Shawna      850297         Ms.              W      Buck      F
# Nathaniel   304721         Mr.              Z     Burke      M
# Elisabeth   412317        Drs.              W    Foster      F
#
#                                  E Mail
# First Name
# Shawna            shawna.buck@gmail.com
# Nathaniel   nathaniel.burke@walmart.com
# Elisabeth    elisabeth.foster@gmail.com

# %%
del data['Shawna','E Mail']

# %%
data
# Out:
#             Emp ID Name Prefix Middle Initial  Last Name Gender  \
# First Name
# Shawna      850297         Ms.              W       Buck      F
# Nathaniel   304721         Mr.              Z      Burke      M
# Elisabeth   412317        Drs.              W     Foster      F
# Briana      621375        Mrs.              C  Lancaster      F
# Estella     787549        Hon.              L     Potter      F
# ...            ...         ...            ...        ...    ...
# Bonnie      568435         Ms.              K      Baker      F
# Luke        597409         Mr.              S     Turner      M
# Eva         359608        Hon.              S     Holman      F
# Maritza     803426        Mrs.              H  Christian      F
# Phyllis     669618        Drs.              H     Dudley      F
#
#                                      E Mail
# First Name
# Shawna                               naveen
# Nathaniel       nathaniel.burke@walmart.com
# ...

# %%
data.loc['Nathaniel','E Mail']
# Out:
# First Name
# Nathaniel       nathaniel.burke@walmart.com
# Nathaniel    nathaniel.bates@exxonmobil.com
# Name: E Mail, dtype: object

# %%
data.index
# Out:
# Index(['Shawna', 'Nathaniel', 'Elisabeth', 'Briana', 'Estella', 'Lamont',
#        'Melinda', 'Shanna', 'Jasmine', 'Madge',
#        ...
#        'Alberta', 'Kerri', 'Olin', 'Stefan', 'Cody', 'Bonnie', 'Luke', 'Eva',
#        'Maritza', 'Phyllis'],
#       dtype='object', name='First Name', length=1000)

# %%
# using where condition
mask=data['Gender']=='M'
data.where(mask)
# Out:
#               Emp ID Name Prefix Middle Initial Last Name Gender  \
# First Name
# Shawna           NaN         NaN            NaN       NaN    NaN
# Nathaniel   304721.0         Mr.              Z     Burke      M
# Elisabeth        NaN         NaN            NaN       NaN    NaN
# Briana           NaN         NaN            NaN       NaN    NaN
# Estella          NaN         NaN            NaN       NaN    NaN
# ...              ...         ...            ...       ...    ...
# Bonnie           NaN         NaN            NaN       NaN    NaN
# Luke        597409.0         Mr.              S    Turner      M
# Eva              NaN         NaN            NaN       NaN    NaN
# Maritza          NaN         NaN            NaN       NaN    NaN
# Phyllis          NaN         NaN            NaN       NaN    NaN
#
#                                  E Mail
# First Name
# Shawna                              NaN
# Nathaniel   nathaniel.burke@walmart.com
# ...

# %%
data.columns
# Out:
# Index(['Emp ID', 'Name Prefix', 'Middle Initial', 'Last Name', 'Gender',
#        'E Mail'],
#       dtype='object')

# %%
data.columns[columns_name.replace(' ','_')for columnname in data.columns]
# Out:
#   File "<ipython-input-50-fe1141f832b5>", line 1
#     data.columns[columns_name.replace(' ','_'),for columnname in data.columns]
#                                                ^
# SyntaxError: invalid syntax

# %%
email=data['E Mail'].copy()

# %%
email.head(3)
# Out:
# First Name
# Shawna                            naveen
# Nathaniel    nathaniel.burke@walmart.com
# Elisabeth     elisabeth.foster@gmail.com
# Name: E Mail, dtype: object

# %%
#working with text data
# common string methods .lower(),.upper(),title(),.len()
data
# Out:
#             Emp ID Name Prefix Middle Initial  Last Name Gender  \
# First Name
# Shawna      850297         Ms.              W       Buck      F
# Nathaniel   304721         Mr.              Z      Burke      M
# Elisabeth   412317        Drs.              W     Foster      F
# Briana      621375        Mrs.              C  Lancaster      F
# Estella     787549        Hon.              L     Potter      F
# ...            ...         ...            ...        ...    ...
# Bonnie      568435         Ms.              K      Baker      F
# Luke        597409         Mr.              S     Turner      M
# Eva         359608        Hon.              S     Holman      F
# Maritza     803426        Mrs.              H  Christian      F
# Phyllis     669618        Drs.              H     Dudley      F
#
#                                      E Mail
# First Name
# Shawna                               naveen
# Nathaniel       nathaniel.burke@walmart.com
# ...

# %%
data['Last Name']=data['Last Name'].sort_values().str.lower()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-27b4b7924864> in <module>
# ----> 1 data['Last Name']=data['Last Name'].sort_values().str.lower()
#
# c:\users\hello\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3038         else:
#    3039             # set column
# -> 3040             self._set_item(key, value)
#    3041
#    3042     def _setitem_slice(self, key: slice, value):
#
# c:\users\hello\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3114         """
#    3115         self._ensure_valid_index(value)
# -> 3116         value = self._sanitize_column(key, value)
#    3117         NDFrame._set_item(self, key, value)
#    3118
#
# ...

# %%
data['E Mail']=data['E Mail'].str.upper()

# %%
email=data['E Mail'].sort_values().copy()

# %%
email
# Out:
# First Name
# Abdul       ABDUL.BARNETT@HOTMAIL.COM
# Abraham          ABRAHAM.MAYO@IBM.COM
# Adam            ADAM.BARTLETT@AOL.COM
# Adam              ADAM.KIRBY@YAHOO.CA
# Adele           ADELE.SCOTT@YAHOO.COM
#                       ...
# Yvette     YVETTE.BENTLEY@HOTMAIL.COM
# Yvette          YVETTE.RIVERS@IBM.COM
# Yvette        YVETTE.WARNER@YAHOO.COM
# Zachary       ZACHARY.GREGORY@COX.NET
# Zachery    ZACHERY.HARVEY@WALMART.COM
# Name: E Mail, Length: 1000, dtype: object

# %%
data.sort_values('E Mail',inplace=True)

# %%
data.sort_index(inplace=True)

# %%
data
# Out:
#             Emp ID Name Prefix Middle Initial Last Name Gender  \
# First Name
# Abdul       245059         Mr.              K       NaN      M
# Abraham     707856         Mr.              H       NaN      M
# Adam        713805         Mr.              I       NaN      M
# Adam        141178         Mr.              X       NaN      M
# Adele       456816         Ms.              Y       NaN      F
# ...            ...         ...            ...       ...    ...
# Yvette      281794        Mrs.              X       NaN      F
# Yvette      249410         Ms.              C       NaN      F
# Yvette      633255        Hon.              U       NaN      F
# Zachary     135089       Prof.              G       NaN      M
# Zachery     471961         Dr.              D       NaN      M
#
#                                 E Mail
# First Name
# Abdul        ABDUL.BARNETT@HOTMAIL.COM
# Abraham           ABRAHAM.MAYO@IBM.COM
# Adam             ADAM.BARTLETT@AOL.COM
# ...
