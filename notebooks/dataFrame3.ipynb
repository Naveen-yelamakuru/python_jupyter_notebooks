# %%
import pandas as pd
data=pd.read_csv('record.csv')

# %%
# delete columns
data.columns
# Out:
# Index(['Emp ID', 'Name Prefix', 'First Name', 'Middle Initial', 'Last Name',
#        'Gender', 'E Mail', 'Father's Name', 'Mother's Name',
#        'Mother's Maiden Name', 'Date of Birth', 'Time of Birth', 'Age in Yrs.',
#        'Weight in Kgs.', 'Date of Joining', 'Quarter of Joining',
#        'Half of Joining', 'Year of Joining', 'Month of Joining',
#        'Month Name of Joining', 'Short Month', 'Day of Joining',
#        'DOW of Joining', 'Short DOW', 'Age in Company (Years)', 'Salary',
#        'Last % Hike', 'SSN', 'Phone No. ', 'Place Name', 'County', 'City',
#        'State', 'Zip', 'Region', 'User Name', 'Password'],
#       dtype='object')

# %%
data.drop('Salary',axis=1,inplace=True)

# %%
data.drop('Day of Joining',axis=1,inplace=True)

# %%
#data.drop(columns=["Fathers's Name","Middle Initial"],axis=1,inplace=True)
# another way of deletion
data.drop(['Place Name','Age in Company (Years)'],axis=1,inplace=True)
#data.drop('SSN',axis=1,inplace=True)
data.columns
# Out:
# Index(['Emp ID', 'Name Prefix', 'First Name', 'Middle Initial', 'Last Name',
#        'Gender', 'E Mail', 'Father's Name', 'Mother's Name',
#        'Mother's Maiden Name', 'Date of Birth', 'Time of Birth', 'Age in Yrs.',
#        'Weight in Kgs.', 'Date of Joining', 'Quarter of Joining',
#        'Half of Joining', 'Year of Joining', 'Month of Joining',
#        'Month Name of Joining', 'Short Month', 'DOW of Joining', 'Short DOW',
#        'Last % Hike', 'SSN', 'Phone No. ', 'County', 'City', 'State', 'Zip',
#        'Region', 'User Name', 'Password'],
#       dtype='object')

# %%
data.drop(["Mother's Name", "Mother's Maiden Name",
       'Date of Birth', 'Time of Birth', 'Age in Yrs.', 'Weight in Kgs.',
       'Date of Joining', 'Quarter of Joining', 'Half of Joining',
       'Year of Joining', 'Month of Joining', 'Month Name of Joining'],axis=1,inplace=True)

# %%
data.columns
# Out:
# Index(['Emp ID', 'Name Prefix', 'First Name', 'Middle Initial', 'Last Name',
#        'Gender', 'E Mail', 'Father's Name', 'Short Month', 'DOW of Joining',
#        'Short DOW', 'Last % Hike', 'SSN', 'Phone No. ', 'County', 'City',
#        'State', 'Zip', 'Region', 'User Name', 'Password'],
#       dtype='object')

# %%
data.drop(['Short Month', 'DOW of Joining', 'Short DOW',
       'Last % Hike', 'Phone No. ', 'User Name'],axis=1,inplace=True)

# %%
data=data.head(10)

# %%
data
# Out:
#    Emp ID Name Prefix First Name Middle Initial  Last Name Gender  \
# 0  850297         Ms.     Shawna              W       Buck      F
# 1  304721         Mr.  Nathaniel              Z      Burke      M
# 2  412317        Drs.  Elisabeth              W     Foster      F
# 3  621375        Mrs.     Briana              C  Lancaster      F
# 4  787549        Hon.    Estella              L     Potter      F
# 5  520092         Mr.     Lamont              L      Woods      M
# 6  795934         Ms.    Melinda              L      Lopez      F
# 7  159108        Mrs.     Shanna              U      Silva      F
# 8  330816         Ms.    Jasmine              J    Freeman      F
# 9  532002         Ms.      Madge              V    Sargent      F
#
#                         E Mail      Father's Name          SSN  \
# 0        shawna.buck@gmail.com       Rosario Buck  222-11-7603
# 1  nathaniel.burke@walmart.com      Derrick Burke  550-99-9897
# ...

# %%
# change columns names 1St way
data.columns
# Out:
# Index(['Emp ID', 'Name Prefix', 'First Name', 'Middle Initial', 'Last Name',
#        'Gender', 'E Mail', 'Father's Name', 'SSN', 'County', 'City', 'State',
#        'Zip', 'Region', 'Password'],
#       dtype='object')

# %%
data.drop(['Zip','State','Region','SSN','Password','City','County'],axis=1,inplace=True)

# %%
data.rename(columns={'Name Prefix':'Name_Of_Student','First Name':'Full_Name'},inplace=True)
data.rename(mapper={'Middle Initial':'Name_Of_College'},axis=1,inplace=True)
data.drop(columns=["Father's Name"],inplace=True)
data.rename(columns={'Emp ID':'Roll_No'},inplace=True)
data
# Out:
#    Roll_No Name_Of_Student  Full_Name Name_Of_College  Last Name Gender  \
# 0   850297             Ms.     Shawna               W       Buck      F
# 1   304721             Mr.  Nathaniel               Z      Burke      M
# 2   412317            Drs.  Elisabeth               W     Foster      F
# 3   621375            Mrs.     Briana               C  Lancaster      F
# 4   787549            Hon.    Estella               L     Potter      F
# 5   520092             Mr.     Lamont               L      Woods      M
# 6   795934             Ms.    Melinda               L      Lopez      F
# 7   159108            Mrs.     Shanna               U      Silva      F
# 8   330816             Ms.    Jasmine               J    Freeman      F
# 9   532002             Ms.      Madge               V    Sargent      F
#
#                         E Mail
# 0        shawna.buck@gmail.com
# 1  nathaniel.burke@walmart.com
# 2   elisabeth.foster@gmail.com
# 3   briana.lancaster@yahoo.com
# ...

# %%
data
data.rename(columns={'Emp ID':'Roll_No'},inplace=True)

# %%
data
# Out:
#    Roll_No Name_Of_Student  Full_Name Name_Of_College  Last Name Gender  \
# 0   850297             Ms.     Shawna               W       Buck      F
# 1   304721             Mr.  Nathaniel               Z      Burke      M
# 2   412317            Drs.  Elisabeth               W     Foster      F
# 3   621375            Mrs.     Briana               C  Lancaster      F
# 4   787549            Hon.    Estella               L     Potter      F
# 5   520092             Mr.     Lamont               L      Woods      M
# 6   795934             Ms.    Melinda               L      Lopez      F
# 7   159108            Mrs.     Shanna               U      Silva      F
# 8   330816             Ms.    Jasmine               J    Freeman      F
# 9   532002             Ms.      Madge               V    Sargent      F
#
#                         E Mail
# 0        shawna.buck@gmail.com
# 1  nathaniel.burke@walmart.com
# 2   elisabeth.foster@gmail.com
# 3   briana.lancaster@yahoo.com
# ...

# %%
data.set_index('Roll_No')
# Out:
#         Name_Of_Student  Full_Name Name_Of_College  Last Name Gender  \
# Roll_No
# 850297              Ms.     Shawna               W       Buck      F
# 304721              Mr.  Nathaniel               Z      Burke      M
# 412317             Drs.  Elisabeth               W     Foster      F
# 621375             Mrs.     Briana               C  Lancaster      F
# 787549             Hon.    Estella               L     Potter      F
# 520092              Mr.     Lamont               L      Woods      M
# 795934              Ms.    Melinda               L      Lopez      F
# 159108             Mrs.     Shanna               U      Silva      F
# 330816              Ms.    Jasmine               J    Freeman      F
# 532002              Ms.      Madge               V    Sargent      F
#
#                               E Mail
# Roll_No
# 850297         shawna.buck@gmail.com
# 304721   nathaniel.burke@walmart.com
# 412317    elisabeth.foster@gmail.com
# ...

# %%
mask=data['Name_Of_College']=='Z'
data.loc[mask,"Name_Of_College"]='JNTU'

# %%
mask=data['Name_Of_College']=='L'
data.loc[mask,"Name_Of_College"]='PVK COLLEGE'

# %%
mask=data['Name_Of_College']=='W'
data.loc[mask,"Name_Of_College"]='BALAJI ENGINEERING COLLEGE'
mask=data['Name_Of_College']=='J'
data.loc[mask,"Name_Of_College"]='ARTS COLLEGE'

# %%
data
# Out:
#    Roll_No Name_Of_Student  Full_Name             Name_Of_College  Last Name  \
# 0   850297             Ms.     Shawna  BALAJI ENGINEERING COLLEGE       Buck
# 1   304721             Mr.  Nathaniel                        JNTU      Burke
# 2   412317            Drs.  Elisabeth  BALAJI ENGINEERING COLLEGE     Foster
# 3   621375            Mrs.     Briana                           C  Lancaster
# 4   787549            Hon.    Estella                 PVK COLLEGE     Potter
# 5   520092             Mr.     Lamont                 PVK COLLEGE      Woods
# 6   795934             Ms.    Melinda                 PVK COLLEGE      Lopez
# 7   159108            Mrs.     Shanna                           U      Silva
# 8   330816             Ms.    Jasmine                ARTS COLLEGE    Freeman
# 9   532002             Ms.      Madge                           V    Sargent
#
#   Gender                       E Mail
# 0      F        shawna.buck@gmail.com
# 1      M  nathaniel.burke@walmart.com
# ...

# %%
mask=data['Name_Of_College']=='C'
data.loc[mask,"Name_Of_College"]='NAVEEN ENGINEERING COLLEGE'
mask=data['Name_Of_College']=='U'
data.loc[mask,"Name_Of_College"]='REETHU ENGINEERING COLLEGE'
mask=data['Name_Of_College']=='V'
data.loc[mask,"Name_Of_College"]='NARAYANA ENGINEERING COLLEGE'

# %%
data
# Out:
#    Roll_No Name_Of_Student  Full_Name               Name_Of_College  \
# 0   850297             Ms.     Shawna    BALAJI ENGINEERING COLLEGE
# 1   304721             Mr.  Nathaniel                          JNTU
# 2   412317            Drs.  Elisabeth    BALAJI ENGINEERING COLLEGE
# 3   621375            Mrs.     Briana    NAVEEN ENGINEERING COLLEGE
# 4   787549            Hon.    Estella                   PVK COLLEGE
# 5   520092             Mr.     Lamont                   PVK COLLEGE
# 6   795934             Ms.    Melinda                   PVK COLLEGE
# 7   159108            Mrs.     Shanna    REETHU ENGINEERING COLLEGE
# 8   330816             Ms.    Jasmine                  ARTS COLLEGE
# 9   532002             Ms.      Madge  NARAYANA ENGINEERING COLLEGE
#
#    Last Name Gender                       E Mail
# 0       Buck      F        shawna.buck@gmail.com
# 1      Burke      M  nathaniel.burke@walmart.com
# 2     Foster      F   elisabeth.foster@gmail.com
# ...

# %%
data.rename(columns={'Name_Of_Student':'Location','Full_Name':'First_Name'},inplace=True)

# %%
data
# Out:
#    Roll_No Location First_Name               Name_Of_College  Last Name  \
# 0   850297      Ms.     Shawna    BALAJI ENGINEERING COLLEGE       Buck
# 1   304721      Mr.  Nathaniel                          JNTU      Burke
# 2   412317     Drs.  Elisabeth    BALAJI ENGINEERING COLLEGE     Foster
# 3   621375     Mrs.     Briana    NAVEEN ENGINEERING COLLEGE  Lancaster
# 4   787549     Hon.    Estella                   PVK COLLEGE     Potter
# 5   520092      Mr.     Lamont                   PVK COLLEGE      Woods
# 6   795934      Ms.    Melinda                   PVK COLLEGE      Lopez
# 7   159108     Mrs.     Shanna    REETHU ENGINEERING COLLEGE      Silva
# 8   330816      Ms.    Jasmine                  ARTS COLLEGE    Freeman
# 9   532002      Ms.      Madge  NARAYANA ENGINEERING COLLEGE    Sargent
#
#   Gender                       E Mail
# 0      F        shawna.buck@gmail.com
# 1      M  nathaniel.burke@walmart.com
# 2      F   elisabeth.foster@gmail.com
# ...

# %%
mask=data['Location']=='Ms.'
data.loc[mask,'Location']='Anantapur'
mask=data['Location']=='Mrs.'
data.loc[mask,'Location']='kadiri'
mask=data['Location']=='Drs.'
data.loc[mask,'Location']='hydrabad'
mask=data['Location']=='Hon.'
data.loc[mask,'Location']='banglore'

# %%
mask=data['Location']=='Mr.'
data.loc[mask,'Location']='uppalapadu'
data
# Out:
#    Roll_No    Location First_Name               Name_Of_College  Last Name  \
# 0   850297   Anantapur     Shawna    BALAJI ENGINEERING COLLEGE       Buck
# 1   304721  uppalapadu  Nathaniel                          JNTU      Burke
# 2   412317    hydrabad  Elisabeth    BALAJI ENGINEERING COLLEGE     Foster
# 3   621375      kadiri     Briana    NAVEEN ENGINEERING COLLEGE  Lancaster
# 4   787549    banglore    Estella                   PVK COLLEGE     Potter
# 5   520092  uppalapadu     Lamont                   PVK COLLEGE      Woods
# 6   795934   Anantapur    Melinda                   PVK COLLEGE      Lopez
# 7   159108      kadiri     Shanna    REETHU ENGINEERING COLLEGE      Silva
# 8   330816   Anantapur    Jasmine                  ARTS COLLEGE    Freeman
# 9   532002   Anantapur      Madge  NARAYANA ENGINEERING COLLEGE    Sargent
#
#   Gender                       E Mail
# 0      F        shawna.buck@gmail.com
# 1      M  nathaniel.burke@walmart.com
# ...

# %%
data=data.set_index('Roll_No')

# %%
data
# Out:
#            Location First_Name               Name_Of_College  Last Name  \
# Roll_No
# 850297    Anantapur     Shawna    BALAJI ENGINEERING COLLEGE       Buck
# 304721   uppalapadu  Nathaniel                          JNTU      Burke
# 412317     hydrabad  Elisabeth    BALAJI ENGINEERING COLLEGE     Foster
# 621375       kadiri     Briana    NAVEEN ENGINEERING COLLEGE  Lancaster
# 787549     banglore    Estella                   PVK COLLEGE     Potter
# 520092   uppalapadu     Lamont                   PVK COLLEGE      Woods
# 795934    Anantapur    Melinda                   PVK COLLEGE      Lopez
# 159108       kadiri     Shanna    REETHU ENGINEERING COLLEGE      Silva
# 330816    Anantapur    Jasmine                  ARTS COLLEGE    Freeman
# 532002    Anantapur      Madge  NARAYANA ENGINEERING COLLEGE    Sargent
# 850297          NaN        NaN                           NaN        NaN
#
#         Gender             E Mail
# Roll_No
# 850297    True  ynaveen@gmail.com
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10 entries, 850297 to 532002
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Location         10 non-null     object
#  1   First_Name       10 non-null     object
#  2   Name_Of_College  10 non-null     object
#  3   Last Name        10 non-null     object
#  4   Gender           10 non-null     object
#  5   E Mail           10 non-null     object
# dtypes: object(6)
# memory usage: 320.0+ bytes

# %%
data['Gender']=data['Gender'].astype('bool')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10 entries, 850297 to 532002
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Location         10 non-null     object
#  1   First_Name       10 non-null     object
#  2   Name_Of_College  10 non-null     object
#  3   Last Name        10 non-null     object
#  4   Gender           10 non-null     bool
#  5   E Mail           10 non-null     object
# dtypes: bool(1), object(5)
# memory usage: 290.0+ bytes

# %%
# change selected values
data.loc['850297','E Mail']='rnaveen@gmail.com'

# %%
data.loc['850297','E Mail']
# Out:
# 'rnaveen@gmail.com'

# %%
data.loc['412317','Gender']='Male'

# %%
data['Gender']='Male'

# %%
data.loc['850297','Gender']='rmail'

# %%
data.loc['850297']
# Out:
# Location                         NaN
# First_Name                       NaN
# Name_Of_College                  NaN
# Last Name                        NaN
# Gender                         rmail
# E Mail             rnaveen@gmail.com
# Name: 850297, dtype: object

# %%
data.set_index('Location')
# Out:
#            First_Name               Name_Of_College  Last Name Gender  \
# Location
# Anantapur      Shawna    BALAJI ENGINEERING COLLEGE       Buck   Male
# uppalapadu  Nathaniel                          JNTU      Burke   Male
# hydrabad    Elisabeth    BALAJI ENGINEERING COLLEGE     Foster   Male
# kadiri         Briana    NAVEEN ENGINEERING COLLEGE  Lancaster   Male
# banglore      Estella                   PVK COLLEGE     Potter   Male
# uppalapadu     Lamont                   PVK COLLEGE      Woods   Male
# Anantapur     Melinda                   PVK COLLEGE      Lopez   Male
# kadiri         Shanna    REETHU ENGINEERING COLLEGE      Silva   Male
# Anantapur     Jasmine                  ARTS COLLEGE    Freeman   Male
# Anantapur       Madge  NARAYANA ENGINEERING COLLEGE    Sargent   Male
# NaN               NaN                           NaN        NaN  rmail
# NaN               NaN                           NaN        NaN   Male
# ...

# %%
data.loc['uppalapadu','E Mail']
# Out:
# nan

# %%
data.dropna(subset=['mail'])
# Out:
#            Location First_Name Name_Of_College Last Name Gender E Mail    mail
# Roll_No
# uppalapadu      NaN        NaN             NaN       NaN    NaN    NaN  killer

# %%
data.set_index('Location')
data.reset_index()
# Out:
#        Roll_No                 Location               First_Name  \
# 0       850297                Anantapur                   Shawna
# 1       304721               uppalapadu                Nathaniel
# 2       412317                 hydrabad                Elisabeth
# 3       621375                   kadiri                   Briana
# 4       787549                 banglore                  Estella
# 5       520092               uppalapadu                   Lamont
# 6       795934                Anantapur                  Melinda
# 7       159108                   kadiri                   Shanna
# 8       330816                Anantapur                  Jasmine
# 9       532002                Anantapur                    Madge
# 10      850297  fill with accepted mail  fill with accepted mail
# 11      412317  fill with accepted mail  fill with accepted mail
# 12  uppalapadu  fill with accepted mail  fill with accepted mail
#
# ...

# %%
del data['mail']

# %%
data.drop(['850297','412317'],inplace=True)

# %%
data.drop('uppalapadu',inplace=True)
data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-176-2ffe26560824> in <module>
# ----> 1 data.drop('uppalapadu',inplace=True)
#       2 data
#
# c:\users\hello\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4160                 weight  1.0     0.8
#    4161         """
# -> 4162         return super().drop(
#    4163             labels=labels,
#    4164             axis=axis,
#
# c:\users\hello\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3882         for axis, labels in axes.items():
#    3883             if labels is not None:
# -> 3884                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3885
# ...

# %%
data.loc['850297','E Mail']='killer'

# %%
data.loc['850297','E Mail']
# Out:
# 'killer'

# %%
data.loc['850297']
# Out:
# Location              NaN
# First_Name            NaN
# Name_Of_College       NaN
# Last Name             NaN
# Gender                NaN
# E Mail             killer
# Name: 850297, dtype: object

# %%
data
# Out:
#            Location First_Name               Name_Of_College  Last Name  \
# Roll_No
# 850297    Anantapur     Shawna    BALAJI ENGINEERING COLLEGE       Buck
# 304721   uppalapadu  Nathaniel                          JNTU      Burke
# 412317     hydrabad  Elisabeth    BALAJI ENGINEERING COLLEGE     Foster
# 621375       kadiri     Briana    NAVEEN ENGINEERING COLLEGE  Lancaster
# 787549     banglore    Estella                   PVK COLLEGE     Potter
# 520092   uppalapadu     Lamont                   PVK COLLEGE      Woods
# 795934    Anantapur    Melinda                   PVK COLLEGE      Lopez
# 159108       kadiri     Shanna    REETHU ENGINEERING COLLEGE      Silva
# 330816    Anantapur    Jasmine                  ARTS COLLEGE    Freeman
# 532002    Anantapur      Madge  NARAYANA ENGINEERING COLLEGE    Sargent
# 850297          NaN        NaN                           NaN        NaN
#
#         Gender             E Mail
# Roll_No
# 850297    Male  ynaveen@gmail.com
# ...

# %%
data[mail]=data.fillna('fill with accepted mail',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-150-96aa2f29ec73> in <module>
# ----> 1 data[mail]=data.fillna('fill with accepted mail',inplace=True)
#
# NameError: name 'mail' is not defined

# %%
data.drop('850297',inplace=True)

# %%
data.reset_index()
# Out:
#    Roll_No    Location First_Name               Name_Of_College  Last Name  \
# 0   850297   Anantapur     Shawna    BALAJI ENGINEERING COLLEGE       Buck
# 1   304721  uppalapadu  Nathaniel                          JNTU      Burke
# 2   412317    hydrabad  Elisabeth    BALAJI ENGINEERING COLLEGE     Foster
# 3   621375      kadiri     Briana    NAVEEN ENGINEERING COLLEGE  Lancaster
# 4   787549    banglore    Estella                   PVK COLLEGE     Potter
# 5   520092  uppalapadu     Lamont                   PVK COLLEGE      Woods
# 6   795934   Anantapur    Melinda                   PVK COLLEGE      Lopez
# 7   159108      kadiri     Shanna    REETHU ENGINEERING COLLEGE      Silva
# 8   330816   Anantapur    Jasmine                  ARTS COLLEGE    Freeman
# 9   532002   Anantapur      Madge  NARAYANA ENGINEERING COLLEGE    Sargent
#
#   Gender             E Mail
# 0   Male  ynaveen@gmail.com
# 1   Male  ynaveen@gmail.com
# 2   Male  ynaveen@gmail.com
# ...

# %%
data.set_index("First_Name",inplace=True)

# %%
data.columns
# Out:
# Index(['Location', 'Name_Of_College', 'Last Name', 'Gender', 'E Mail'], dtype='object')

# %%
data.loc['Shawna']
# Out:
# Location                             Anantapur
# Name_Of_College     BALAJI ENGINEERING COLLEGE
# Last Name                                 Buck
# Gender                                    Male
# E Mail                                  killer
# (Shawna, E Mail)                        killer
# Name: Shawna, dtype: object

# %%
data.loc['Shawna','E Mail']='killer'

# %%
data
# Out:
#               Location               Name_Of_College  Last Name Gender  \
# First_Name
# Shawna       Anantapur    BALAJI ENGINEERING COLLEGE       Buck   Male
# Nathaniel   uppalapadu                          JNTU      Burke   Male
# Elisabeth     hydrabad    BALAJI ENGINEERING COLLEGE     Foster   Male
# Briana          kadiri    NAVEEN ENGINEERING COLLEGE  Lancaster   Male
# Estella       banglore                   PVK COLLEGE     Potter   Male
# Lamont      uppalapadu                   PVK COLLEGE      Woods   Male
# Melinda      Anantapur                   PVK COLLEGE      Lopez   Male
# Shanna          kadiri    REETHU ENGINEERING COLLEGE      Silva   Male
# Jasmine      Anantapur                  ARTS COLLEGE    Freeman   Male
# Madge        Anantapur  NARAYANA ENGINEERING COLLEGE    Sargent   Male
# NaN                NaN                           NaN        NaN    NaN
#
#                        E Mail (Shawna, E Mail)
# First_Name
# ...

# %%
# thrid way
data.columns=['Name_Of_Student','Full_Name','Name_Of_College','Total_Score','Gender','E_mail']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-73989651f7e7> in <module>
#       1 # thrid way
# ----> 2 data.columns=['Name_Of_Student','Full_Name','Name_Of_College','Total_Score','Gender','E_mail']
#
# c:\users\hello\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5147         try:
#    5148             object.__getattribute__(self, name)
# -> 5149             return object.__setattr__(self, name, value)
#    5150         except AttributeError:
#    5151             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# c:\users\hello\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     562     def _set_axis(self, axis: int, labels: Index) -> None:
# ...

# %%
data

# %%
# add new column 
data['Serial_number']='101'

# %%
#set as custom index name
data.set_index('Serial_number',inplace=True)

# %%
data['Serial_number']

# %%
 def serial(number):
         return int(number)+1
data.apply(serial)

# %%
data

# %%
data.info()

# %%
# change the specific column values
change=data['Gender']=='M'

# %%
data.loc[change,'Gender']='Male'

# %%
data
# Out:
#    Emp ID Name_Of_Student  Full_Name Name_Of_College  Last Name Gender  \
# 0  850297             Ms.     Shawna               W       Buck      F
# 1  304721             Mr.  Nathaniel               Z      Burke   Male
# 2  412317            Drs.  Elisabeth               W     Foster      F
# 3  621375            Mrs.     Briana               C  Lancaster      F
# 4  787549            Hon.    Estella               L     Potter      F
# 5  520092             Mr.     Lamont               L      Woods   Male
# 6  795934             Ms.    Melinda               L      Lopez      F
# 7  159108            Mrs.     Shanna               U      Silva      F
# 8  330816             Ms.    Jasmine               J    Freeman      F
# 9  532002             Ms.      Madge               V    Sargent      F
#
#                         E Mail      Father's Name          SSN  \
# 0        shawna.buck@gmail.com       Rosario Buck  222-11-7603
# ...

# %%
change=data['Gender']=="F"
data.loc[change,"Gender"]='Female'

# %%
data
# Out:
#            Location First_Name               Name_Of_College  Last Name  \
# Roll_No
# 850297    Anantapur     Shawna    BALAJI ENGINEERING COLLEGE       Buck
# 304721   uppalapadu  Nathaniel                          JNTU      Burke
# 412317     hydrabad  Elisabeth    BALAJI ENGINEERING COLLEGE     Foster
# 621375       kadiri     Briana    NAVEEN ENGINEERING COLLEGE  Lancaster
# 787549     banglore    Estella                   PVK COLLEGE     Potter
# 520092   uppalapadu     Lamont                   PVK COLLEGE      Woods
# 795934    Anantapur    Melinda                   PVK COLLEGE      Lopez
# 159108       kadiri     Shanna    REETHU ENGINEERING COLLEGE      Silva
# 330816    Anantapur    Jasmine                  ARTS COLLEGE    Freeman
# 532002    Anantapur      Madge  NARAYANA ENGINEERING COLLEGE    Sargent
# 850297          NaN        NaN                           NaN        NaN
#
#         Gender             E Mail
# Roll_No
# 850297    True  ynaveen@gmail.com
# ...

# %%
# change single row and multiple column values
